# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/ieee-fraud-detection/sample_submission.csv
# /kaggle/input/ieee-fraud-detection/test_identity.csv
# /kaggle/input/ieee-fraud-detection/train_identity.csv
# /kaggle/input/ieee-fraud-detection/test_transaction.csv
# /kaggle/input/ieee-fraud-detection/train_transaction.csv

# %%
test_id = pd.read_csv('/kaggle/input/ieee-fraud-detection/test_identity.csv')
test_trans = pd.read_csv('/kaggle/input/ieee-fraud-detection/test_transaction.csv')

# %%
test=pd.merge(test_trans,test_id,on='TransactionID',how='left')
test.columns = [col.replace('id-', 'id_') for col in test.columns]

# %%
del test_trans,test_id

# %%
# !pip install mlflow dagshub
import dagshub
import mlflow
dagshub.init(repo_owner='skara-21', repo_name='Assignment2_Fraud_Detection', mlflow=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 43.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 80.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 692.3/692.3 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.2/203.2 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: dacite
#     Found existing installation: dacite 1.9.2
# ...

# %%
import mlflow.sklearn

model_xgb = mlflow.sklearn.load_model("runs:/2a993601adc34b838b8de9b15c6a4fe1/fraud_detection_pipeline")

# model_randF=mlflow.sklearn.load_model("runs:/2a993601adc34b838b8de9b15c6a4fe1/fraud_detection_pipeline")

# model_randF=mlflow.sklearn.load_model("runs:/2a993601adc34b838b8de9b15c6a4fe1/fraud_detection_pipeline")

model=model_xgb

# %%
prediction = model.predict_proba(test)[:, 1]

predictionDf = pd.DataFrame({
    'TransactionID': test['TransactionID'],
    'isFraud': prediction
})

# %%
predictionDf.to_csv('/kaggle/working/predictions.csv', index=False)
